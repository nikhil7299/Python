# %%
#pip install pandas
import pandas as pd
s1=pd.Series([1,2,3],index=['a','b','c'])
s2=pd.Series((3,4,5),index=['a','c','d'])
print(s1,s2)
# Out:
# a    1
# b    2
# c    3
# dtype: int64 a    3
# c    4
# d    5
# dtype: int64

# %%
df=pd.DataFrame([[1,'x','0000'],[2,'y','1111'],[3,'z','4444']],
                columns=['rollno','name','phone'], index=['p','q','r'])
df
# Out:
#    rollno name phone
# p       1    x  0000
# q       2    y  1111
# r       3    z  4444

# %%
df1=pd.DataFrame({'Name':['x','y','z'],
                  'Rollno':[1,2,3],
                  'mobile':"0000 1111 2222".split()}, index='q r s'.split())
df1
# Out:
#   Name  Rollno mobile
# q    x       1   0000
# r    y       2   1111
# s    z       3   2222

# %%
print(type(df1),type(df1['Name']))
print(df1['Name'])
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.series.Series'>
# q    x
# r    y
# s    z
# Name: Name, dtype: object

# %%
datalist=[['blue','Ball',1.2],
['Green','Pen',1.0],
['Yellow','Pencil',0.6],
['Red','Paper',0.9],
['White','Mug',1.7]]
dfx = pd.DataFrame(datalist,columns=['Color','Object','Price'])
dfx
# Out:
#     Color  Object  Price
# 0    blue    Ball    1.2
# 1   Green     Pen    1.0
# 2  Yellow  Pencil    0.6
# 3     Red   Paper    0.9
# 4   White     Mug    1.7

# %%
dfdict=pd.DataFrame({'Color':['Blue', 'Green', 'Yellow', 'Red', 'White'],
'Object':['Ball', 'Pen', 'Pencil', 'Paper', 'Mug'],
'Price':[1.2, 1.0, 0.6, 0.9, 1.7]})
dfdict
# Out:
#     Color  Object  Price
# 0    Blue    Ball    1.2
# 1   Green     Pen    1.0
# 2  Yellow  Pencil    0.6
# 3     Red   Paper    0.9
# 4   White     Mug    1.7

# %%
import pandas as pd
import numpy as np

exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
dfn=pd.DataFrame(exam_data,index=labels)
# dfn.iloc[0:3]
dfn
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df2=pd.DataFrame({"rollno":pd.Series([1,2,3]),
                "name":pd.Series(['x','y','z'])})
df2
# Out:
#    rollno name
# 0       1    x
# 1       2    y
# 2       3    z

# %%
df1
# Out:
#   Name  Rollno mobile
# q    x       1   0000
# r    y       2   1111
# s    z       3   2222

# %%
type(df1[['Name','mobile']])
# Out:
# pandas.core.frame.DataFrame

# %%
df1['marks']=[87,99,45]
df1
# Out:
#   Name  Rollno mobile  marks
# q    x       1   0000     87
# r    y       2   1111     99
# s    z       3   2222     45

# %%
del df1['marks']

# %%
df1
# Out:
#   Name  Rollno mobile
# q    x       1   0000
# r    y       2   1111
# s    z       3   2222

# %%
mobile=df1.pop('mobile')
print(mobile)
# Out:
# q    0000
# r    1111
# s    2222
# Name: mobile, dtype: object

# %%
df1
# Out:
#   Name  Rollno
# q    x       1
# r    y       2
# s    z       3

# %%
dfx
# Out:
#     Color  Object  Price
# 0    blue    Ball    1.2
# 1   Green     Pen    1.0
# 2  Yellow  Pencil    0.6
# 3     Red   Paper    0.9
# 4   White     Mug    1.7

# %%
dfx.index=['p','q','r','s','t']
dfx
# Out:
#     Color  Object  Price
# p    blue    Ball    1.2
# q   Green     Pen    1.0
# r  Yellow  Pencil    0.6
# s     Red   Paper    0.9
# t   White     Mug    1.7

# %%
dfx.loc[['p','r'],['Color']]
# Out:
#     Color
# p    blue
# r  Yellow

# %%
dfx.iloc[0::2]
# Out:
#     Color  Object  Price
# p    blue    Ball    1.2
# r  Yellow  Pencil    0.6
# t   White     Mug    1.7

# %%
dfx
# Out:
#     Color  Object  Price
# p    blue    Ball    1.2
# q   Green     Pen    1.0
# r  Yellow  Pencil    0.6
# s     Red   Paper    0.9
# t   White     Mug    1.7

# %%
dfx=dfx.append(pd.DataFrame([['black','Pen','2.9']],columns=['Color',"Object","Price"],
                          index=['u']))
dfx
# Out:
#     Color  Object Price
# p    blue    Ball   NaN
# q   Green     Pen   NaN
# r  Yellow  Pencil   NaN
# s     Red   Paper   NaN
# t   White     Mug   NaN
# u   black     Pen   2.9

# %%
dfx.drop('u')
# Out:
#     Color  Object Price
# p    blue    Ball   NaN
# q   Green     Pen   NaN
# r  Yellow  Pencil   NaN
# s     Red   Paper   NaN
# t   White     Mug   NaN

# %%
dfx
# Out:
#     Color  Object Price
# p    blue    Ball   NaN
# q   Green     Pen   NaN
# r  Yellow  Pencil   NaN
# s     Red   Paper   NaN
# t   White     Mug   NaN
# u   black     Pen   2.9

# %%
dfx.drop('u', inplace=True) #inplace to make permanenr=t change

# %%
dfx
# Out:
#     Color  Object Price
# p    blue    Ball   NaN
# q   Green     Pen   NaN
# r  Yellow  Pencil   NaN
# s     Red   Paper   NaN
# t   White     Mug   NaN

# %%
dfx.drop('Price', axis=1, inplace=True)

# %%
dfx
# Out:
#     Color  Object
# p    blue    Ball
# q   Green     Pen
# r  Yellow  Pencil
# s     Red   Paper
# t   White     Mug

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(1,10)
y=2*x
y1=4*x
#plt.plot(x,y,x,y1)
plt.scatter(x,y)
plt.xlabel("x=np.arange(1,10)")
plt.ylabel("y")
plt.show()

# %%
x=np.arange(-10,10)
y=np.sin(x)
plt.plot(x,y)
plt.show()
