# %%
from tkinter import *

top= Tk()
#Write the code to add widgets over here
top.mainloop()

# %%
from tkinter import messagebox

top=Tk()

def hello():
    messagebox.showinfo("Hello Python","Welcome to python")
b=Button(top, text="Click me", command=hello)
b.pack()
top.mainloop()

# %%
top=Tk()
b=Button(top, text="Click me", command=top.destroy, bg="red", activebackground="yellow",
         activeforeground="brown",width=25, height=25, font=10)
b.pack()
top.mainloop()

# %%
top=Tk()
top.geometry("250x250")
b=Button(top, text="Destroy", command=top.destroy)
b.pack(side="left")
b1=Button(top, text="Cllick me", command=hello)
b1.pack(side="right")
top.mainloop()

# %%
top=Tk()
top.geometry("250x250")
b=Button(top, text="Destroy", command=top.destroy)
b.grid(row=0, column=0)
b1=Button(top, text="Cllick me", command=hello)
b1.grid(row=1,column=1)
top.mainloop()

# %%
top=Tk()
def fun():
    selection=v1.get()+v2.get()
    l3.config(text=selection)
top.geometry("450x450")
l1=Label(top, text="Enter the Name")
l1.grid(row=0, column=0)
v1=StringVar()
e1=Entry(top,textvariable=v1)
e1.grid(row=0, column=1)
l2=Label(top, text="Enter the Age")
l2.grid(row=1, column=0)
v2=StringVar()
e2=Entry(top, textvariable=v2)
e2.grid(row=1, column=1)
b=Button(top, text="Click me", command=fun)
b.grid(row=2,column=1)
l3=Label(top)
l3.grid(row=4, column=0)
top.mainloop()

# %%
from tkinter import *
top=Tk()
top.geometry("250x250")
def check():
    value=v1.get()
    if(not(value.isdigit()) or len(value)!=10):
        messagebox.showinfo("Error","Enter valid mobile number")
        
l1=Label(top, text="Enter Mobile Number")
l1.grid(row=0,column=0)
v1=StringVar()
e1=Entry(top,textvariable=v1)
e1.grid(row=0,column=1)
b=Button(top, text="submit",command=check)
b.grid(row=1, column=1)
top.mainloop()

# %%
from tkinter import *
from tkinter import messagebox
def message():
    #messagebox.showinfo("M1","hello")
    #messagebox.showwarning("M2","Warning")
    #messagebox.showerror("M3","Error")
    """v=messagebox.askokcancel("m4","are you sure?")
    print(type(v))"""
    messagebox.askquestion("m5","question")
top=Tk(className="Demo")
b=Button(top,text="click",command=message).place(x=105, y=110)
top.mainloop()

# %%
top=Tk(className="Radio")
def click():
    s=v.get()
    if(s==1):
        l2.config(text="you have selected gender male")
    elif(s==2):
        l2.config(text="you have selected gender Female")
    elif(s==3):
        l2.config(text="you have selected gender others")
    else:
        messagebox.showerror("error","Please select gender"+str(s))
l1=Label(top, text="Select a gender").grid(row=0,column=0)
v=IntVar()
r1=Radiobutton(top,text="Male",variable=v,value=1).grid(row=0,column=1)
r2=Radiobutton(top,text="FeMale",variable=v, value=2).grid(row=0,column=2)
r3=Radiobutton(top,text="others",variable=v,value=3).grid(row=0,column=3)
Button(top,text="click", command=click).grid(row=2,column=1)
l2=Label(top,text="here")
l2.grid(row=3,column=0)
top.mainloop()

# %%
from tkinter import *
top=Tk(className="Checkboxes")
def check():
    print("hello")
    s="Selected languages are "
    if(v1.get()):
        s+=" English"
    if(v2.get()):
        s+="Hindi"
    if(v3.get()):
        s+="Punjabi"
    if(v1.get()==0 and v2.get()==0 and v3.get()==0):
        messagebox.showerror("error","Atleast select one language")
    else:
        l2.config(text=s)
        
l1=Label(top,text="Select languages").grid(row=0,column=0)
v1,v2,v3=IntVar(), IntVar(), IntVar()
c1=Checkbutton(top,text="English",variable=v1,onvalue=1, offvalue=0)
c1.grid(row=0,column=1)
c2=Checkbutton(top,text="Hindi",variable=v2, onvalue=1, offvalue=0)
c2.grid(row=0,column=2)
c3=Checkbutton(top,text="Punjabi",variable=v3, onvalue=1, offvalue=0)
c3.grid(row=0,column=3)
Button(top,text="click",command=check).grid(row=2,column=2)
l2=Label(top)
l2.grid(row=3,column=1)
top.mainloop()

# %%
from tkinter import *
top=Tk("Registration form")
def check():
    s,e="",""
    if(v1.get()==""):
        e+="Please enter a name\n"
    else:
        s+=v1.get()
    if(not(v2.get().isdigit()) or len(v2.get())!=10):
        e+="Please enter a valid mobile number\n"
    else:
        s+=v2.get()
    if(not(v3.get().isdigit()) or len(v3.get())!=6):
        e+="Please enter a valid pin code\n"
    else:
        s+=v3.get()
    if(v.get()):
        if(v.get()==1):
            s+= "Male"
        if(v.get()==2):
            s+="Female"
        if(v.get()==3):
            s+="others"
    else:
        e+="Please select a gender\n"
    if(v4.get()==0 and v5.get()==0 and v6.get()==0):
        e+="Atleast select one subject"
    else:
        if(v4.get()):
            s+=" english"
        if(v5.get()):
            s+="hindi"
        if(v6.get()):
            s+="Punjabi"
    if(e!=""):
        messagebox.showerror("error",e)
    else:
        messagebox.showinfo("Data",s)
        
l1=Label(top, text="Enter Name").grid(row=0,column=0)
v1=StringVar()
e1=Entry(top,textvariable=v1).grid(row=0,column=1)
l2=Label(top, text="Enter Mobile Number").grid(row=1,column=0)
v2=StringVar()
e2=Entry(top,textvariable=v2).grid(row=1,column=1)
l3=Label(top, text="Enter Pincode").grid(row=2,column=0)
v3=StringVar()
e3=Entry(top,textvariable=v3).grid(row=2,column=1)
l4=Label(top, text="Select gender").grid(row=3,column=0)
v=IntVar()
r1=Radiobutton(top,text="Male",variable=v,value=1).grid(row=3,column=1)
r2=Radiobutton(top,text="FeMale",variable=v, value=2).grid(row=3,column=2)
r3=Radiobutton(top,text="others",variable=v,value=3).grid(row=3,column=3)
l5=Label(top,text="Select languages").grid(row=4,column=0)
v4,v5,v6=IntVar(), IntVar(), IntVar()
c1=Checkbutton(top,text="English",variable=v4,onvalue=1, offvalue=0)
c1.grid(row=4,column=1)
c2=Checkbutton(top,text="Hindi",variable=v5, onvalue=1, offvalue=0)
c2.grid(row=4,column=2)
c3=Checkbutton(top,text="Punjabi",variable=v6, onvalue=1, offvalue=0)
c3.grid(row=4,column=3)
Button(top,text="click",command=check).grid(row=5,column=2)
top.mainloop()

# %%
from tkinter import *
from tkmacosx import Button
root=Tk() 
root.geometry("450x450") 
frame=Frame(root) 
Button(frame,text="red",bd=5,bg="red").pack(side="left") 
frame.pack(side="left") 
frame1=Frame(root) 
Button(frame1,text="blue",bd=5,bg="blue").pack(side="left") 
frame1.pack(side="top") 
frame2=Frame(root) 
Button(frame2,text="yellow",bd=5,bg="yellow").pack(side="left") 
frame2.pack(side="right")
frame4=Frame(root) 
Button(frame4,text="green",bd=5,bg="green").pack(side="left") 
frame4.pack(side="bottom") 
root.mainloop()

# %%
from tkinter import * 
from tkinter import messagebox
import tkmacosx
top=Tk("Registration form")
l1=Label(top, text="Enter Name").grid(row=0,column=0)
v1=StringVar()
e1=Entry(top,textvariable=v1).grid(row=0,column=1)
l2=Label(top, text="Enter Mobile Number").grid(row=1,column=0)
v2=StringVar()
e2=Entry(top,textvariable=v2).grid(row=1,column=1)
l3=Label(top, text="Enter Pincode").grid(row=2,column=0)
v3=StringVar()
e3=Entry(top,textvariable=v3).grid(row=2,column=1)
l4=Label(top, text="Select gender").grid(row=3,column=0)
v=IntVar()
r1=Radiobutton(top,text="Male",variable=v,value=1).grid(row=3,column=1)
r2=Radiobutton(top,text="FeMale",variable=v, value=2).grid(row=3,column=2)
r3=Radiobutton(top,text="others",variable=v,value=3).grid(row=3,column=3)
l5=Label(top,text="Select languages").grid(row=4,column=0)
v4,v5,v6=IntVar(), IntVar(), IntVar()
c1=Checkbutton(top,text="English",variable=v4,onvalue=1, offvalue=0)
c1.grid(row=4,column=1)
c2=Checkbutton(top,text="Hindi",variable=v5, onvalue=1, offvalue=0)
c2.grid(row=4,column=2)
c3=Checkbutton(top,text="Punjabi",variable=v6, onvalue=1, offvalue=0)
c3.grid(row=4,column=3)
Button(top,text="click",command=check).grid(row=5,column=2)
top.mainloop()

# %%
from tkinter import *  
  
top = Tk()  
text = Text(top)  
text.insert(INSERT, "Name.....")  
text.insert(END, "Salary.....")  
  
text.pack()  
  
text.tag_add("Write Here", "1.0", "1.4")  
text.tag_add("Click Here", "1.8", "1.13")  
  
text.tag_config("Write Here", background="yellow", foreground="black")  
text.tag_config("Click Here", background="black", foreground="white")  
  
top.mainloop()

# %%
from tkinter import *
from tkinter import messagebox
def selection():
    print(l1.curselection())
    messagebox.showinfo("Scale Value",str(var.get())+l1.get(l1.curselection()[0]))
top=Tk()
var=IntVar()
s=Scale(top, to=600, from_=50,variable=var, orient="horizontal")
s.pack()
l1=Listbox(top,selectmode='single')
l1.insert(1,"Apple")
l1.insert(2,"orange")
l1.insert(3,"Mango")
l1.pack()
Button(top,text="value",command=selection).pack()

top.mainloop()

# %%
from tkinter import *
root=Tk(className="Demo")
i=0
def insert():
    global i
    if(vz.get()==""):
        messagebox.showerror("error","Please enter some value")
    else:
        lz.insert(i,vz.get())
        i+=1
vz=StringVar()
ez=Entry(root,textvariable=vz,bd=5)
ez.pack()
lz=Listbox(root,bd=5)

lz.pack()
Button(root,text="Insert",bd=5, command=insert).pack()
root.mainloop()
